# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
train = pd.read_csv('train.csv')

# %%
plt.boxplot(train.ApplicantIncome)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f1515037dd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1515048c50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f151505af50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f151505a910>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f1515037f10>,
#   <matplotlib.lines.Line2D at 0x7f1515048610>]}

# %%
train.hist(column='ApplicantIncome')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f15151c3c50>]], dtype=object)

# %%
train[train.ApplicantIncome>80000].Loan_Status.value_counts()
# Out:
# N    1
# Name: Loan_Status, dtype: int64

# %%
import seaborn as sns

# %%
A = train[train.ApplicantIncome<10000]

# %%
sns.stripplot(x=A.Credit_History , y = A.ApplicantIncome , jitter=True)

# %%
sns.stripplot(x=A.Credit_History,y = A.LoanAmount ,hue=train.LoanAmount,jitter=True)

# %%
sns.set(color_codes=True)

# %%
sns.distplot(A[A.Credit_History==1].ApplicantIncome)

# %%
sns.distplot(A[A.Credit_History==0].ApplicantIncome,hist=False,rug=True)

# %%
sns.jointplot(x=train.ApplicantIncome,y=train.LoanAmount)

# %%
df = train.groupby(['Gender','Dependents'])['Loan_ID'].count().unstack('Gender').fillna(0)

# %%
df.plot(kind='bar',stacked=True)

# %%
train[train.Gender.isnull()]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 23   LP001050    NaN     Yes          2  Not Graduate            No
# 126  LP001448    NaN     Yes         3+      Graduate            No
# 171  LP001585    NaN     Yes         3+      Graduate            No
# 188  LP001644    NaN     Yes          0      Graduate           Yes
# 314  LP002024    NaN     Yes          0      Graduate            No
# 334  LP002103    NaN     Yes          1      Graduate           Yes
# 460  LP002478    NaN     Yes          0      Graduate           Yes
# 467  LP002501    NaN     Yes          0      Graduate            No
# 477  LP002530    NaN     Yes          2      Graduate            No
# 507  LP002625    NaN      No          0      Graduate            No
# 576  LP002872    NaN     Yes          0      Graduate            No
# 588  LP002925    NaN      No          0      Graduate            No
# 592  LP002933    NaN      No         3+      Graduate           Yes
#
# ...

# %%
sns.stripplot(x=train.Self_Employed,y=train.ApplicantIncome)
